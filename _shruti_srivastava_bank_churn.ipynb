# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("churn data.txt",sep='\t')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.size
# Out:
# 140000

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.describe(include="all")
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# count   10000.000000  10000.000000   10000.000000   10000.000000  10000.00000
# unique           NaN           NaN            NaN            NaN          NaN
# top              NaN           NaN            NaN            NaN          NaN
# freq             NaN           NaN            NaN            NaN          NaN
# mean       38.921800      5.012800   76485.889288       1.530200      0.70550
# std        10.487806      2.892174   62397.405202       0.581654      0.45584
# min        18.000000      0.000000       0.000000       1.000000      0.00000
# 25%        32.000000      3.000000       0.000000       1.000000      0.00000
# 50%        37.000000      5.000000   97198.540000       1.000000      1.00000
# 75%        44.000000      7.000000  127644.240000       2.000000      1.00000
# max        92.000000     10.000000  250898.090000       4.000000      1.00000
#
#         IsActiveMember  EstimatedSalary        Exited
# count     10000.000000     10000.000000  10000.000000
# unique             NaN              NaN           NaN
# top                NaN              NaN           NaN
# freq               NaN              NaN           NaN
# mean          0.515100    100090.239881      0.203700
# std           0.499797     57510.492818      0.402769
# min           0.000000        11.580000      0.000000
# 25%           0.000000     51002.110000      0.000000
# 50%           1.000000    100193.915000      0.000000
# 75%           1.000000    149388.247500      0.000000
# max           1.000000    199992.480000      1.000000

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
sns.countplot(x="Exited",data=df)
plt.show()

# %%
sns.countplot(x='Gender', hue='Exited', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Geography', hue='Exited',data=df)
# Out:
# <Axes: xlabel='Geography', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column]=le.fit_transform(df[column])
# Out:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-18-52430de27b89>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:

# %%
df
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0             0        2736     1115          228          0       0   24
# 1             1        3258     1177          217          2       0   23
# 2             2        2104     2040          111          0       0   24
# 3             3        5435      289          308          0       0   21
# 4             4        6899     1822          459          2       0   25
# ...         ...         ...      ...          ...        ...     ...  ...
# 9995       9995        1599     1999          380          0       1   21
# 9996       9996         161     1336          125          0       1   17
# 9997       9997         717     1570          318          0       0   18
# 9998       9998        4656     2345          381          1       1   24
# 9999       9999        2497     2751          401          0       0   10
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              0          1               1
# 1          1   83807.86              0          0               1
# 2          8  159660.80              2          1               0
# 3          1       0.00              1          0               0
# 4          2  125510.82              0          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              1          1               0
# 9996      10   57369.61              0          1               1
# 9997       7       0.00              0          0               1
# 9998       3   75075.31              1          1               0
# 9999       4  130142.79              0          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
x= df.drop("Exited",axis=1)

# %%
y=df.Exited

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
x_feature=ss.fit_transform(x)

# %%
x_feature
# Out:
# array([[-1.73187761, -0.7840994 , -0.46418322, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [-1.7315312 , -0.6032733 , -0.3909112 , ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-1.73118479, -1.00303063,  0.62898807, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [ 1.73118479, -1.48350152,  0.07353887, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [ 1.7315312 , -0.11899189,  0.98943914, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [ 1.73187761, -0.86689143,  1.4692527 , ...,  0.64609167,
#         -1.03067011, -1.07636976]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x_feature,y,test_size=0.2,random_state=1)

# %%
X_train.shape
# Out:
# (8000, 13)

# %%
X_test.shape
# Out:
# (2000, 13)

# %%
Y_train.shape
# Out:
# (8000,)

# %%
Y_test.shape
# Out:
# (2000,)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
predict=lr.predict(X_test)

# %%
lr.score(X_test,Y_test)
# Out:
# 0.8045

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=30)
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(n_estimators=30)

# %%
rfc.score(X_train,Y_train)
# Out:
# 0.998

# %%
predict=rfc.predict(X_test)

# %%
rfc.score(X_test,Y_test)
# Out:
# 0.861

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,predict)
# Out:
# 0.861

# %%
#Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier()

# %%
gbc.score(X_train,Y_train)
# Out:
# 0.871875

# %%
predict=gbc.predict(X_test)

# %%
gbc.score(X_test,Y_test)
# Out:
# 0.864

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,predict)
ax=plt.axes()
sns.heatmap(cm,annot=True,
           annot_kws={'size':10},
           ax=ax)
plt.title("Confusion_Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,predict))
print(X_train.shape)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1585
#            1       0.81      0.45      0.58       415
#
#     accuracy                           0.86      2000
#    macro avg       0.84      0.71      0.75      2000
# weighted avg       0.86      0.86      0.85      2000
#
# (8000, 13)

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras import utils
import seaborn
model=keras.Sequential([
    keras.layers.Dense(20,input_shape=(13,),activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])
model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 20)                280
#
#  dense_4 (Dense)             (None, 15)                315
#
#  dense_5 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 611 (2.39 KB)
# Trainable params: 611 (2.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train,Y_train,epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 1ms/step - loss: 0.4898 - accuracy: 0.7986
# Epoch 2/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4358 - accuracy: 0.8139
# Epoch 3/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4227 - accuracy: 0.8221
# Epoch 4/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4134 - accuracy: 0.8270
# Epoch 5/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4009 - accuracy: 0.8340
# Epoch 6/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3832 - accuracy: 0.8430
# Epoch 7/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3683 - accuracy: 0.8496
# Epoch 8/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3591 - accuracy: 0.8525
# Epoch 9/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3533 - accuracy: 0.8544
# Epoch 10/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3507 - accuracy: 0.8569
# Epoch 11/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3481 - accuracy: 0.8560
# Epoch 12/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3456 - accuracy: 0.8593
# Epoch 13/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3441 - accuracy: 0.8577
# Epoch 14/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3424 - accuracy: 0.8594
# Epoch 15/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3411 - accuracy: 0.8590
# Epoch 16/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3395 - accuracy: 0.8600
# Epoch 17/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3389 - accuracy: 0.8599
# Epoch 18/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3373 - accuracy: 0.8595
# Epoch 19/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3361 - accuracy: 0.8612
# Epoch 20/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3358 - accuracy: 0.8602
# Epoch 21/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3346 - accuracy: 0.8610
# Epoch 22/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3333 - accuracy: 0.8620
# Epoch 23/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3325 - accuracy: 0.8624
# Epoch 24/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3313 - accuracy: 0.8626
# Epoch 25/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3315 - accuracy: 0.8625
# Epoch 26/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.8631
# Epoch 27/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3303 - accuracy: 0.8626
# Epoch 28/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3288 - accuracy: 0.8630
# Epoch 29/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3278 - accuracy: 0.8643
# Epoch 30/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3279 - accuracy: 0.8633
# Epoch 31/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3267 - accuracy: 0.8641
# Epoch 32/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3262 - accuracy: 0.8645
# Epoch 33/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3258 - accuracy: 0.8659
# Epoch 34/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3257 - accuracy: 0.8650
# Epoch 35/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3244 - accuracy: 0.8656
# Epoch 36/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3236 - accuracy: 0.8658
# Epoch 37/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3237 - accuracy: 0.8674
# Epoch 38/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3229 - accuracy: 0.8668
# Epoch 39/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3220 - accuracy: 0.8666
# Epoch 40/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3216 - accuracy: 0.8668
# Epoch 41/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3213 - accuracy: 0.8677
# Epoch 42/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3210 - accuracy: 0.8676
# Epoch 43/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8676
# Epoch 44/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3198 - accuracy: 0.8698
# Epoch 45/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3194 - accuracy: 0.8673
# Epoch 46/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3189 - accuracy: 0.8686
# Epoch 47/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3186 - accuracy: 0.8692
# Epoch 48/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3182 - accuracy: 0.8690
# Epoch 49/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3183 - accuracy: 0.8700
# Epoch 50/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3181 - accuracy: 0.8684
# Epoch 51/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3165 - accuracy: 0.8700
# Epoch 52/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3166 - accuracy: 0.8685
# Epoch 53/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3167 - accuracy: 0.8700
# Epoch 54/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3152 - accuracy: 0.8696
# Epoch 55/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3158 - accuracy: 0.8705
# Epoch 56/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3156 - accuracy: 0.8698
# Epoch 57/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3149 - accuracy: 0.8711
# Epoch 58/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3146 - accuracy: 0.8720
# Epoch 59/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3150 - accuracy: 0.8723
# Epoch 60/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3148 - accuracy: 0.8710
# Epoch 61/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3137 - accuracy: 0.8714
# Epoch 62/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3129 - accuracy: 0.8715
# Epoch 63/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3131 - accuracy: 0.8726
# Epoch 64/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3129 - accuracy: 0.8730
# Epoch 65/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3124 - accuracy: 0.8734
# Epoch 66/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3127 - accuracy: 0.8706
# Epoch 67/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3116 - accuracy: 0.8733
# Epoch 68/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3120 - accuracy: 0.8723
# Epoch 69/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3118 - accuracy: 0.8717
# Epoch 70/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3113 - accuracy: 0.8723
# Epoch 71/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3107 - accuracy: 0.8736
# Epoch 72/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3104 - accuracy: 0.8721
# Epoch 73/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3103 - accuracy: 0.8724
# Epoch 74/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3104 - accuracy: 0.8724
# Epoch 75/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3098 - accuracy: 0.8729
# Epoch 76/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3099 - accuracy: 0.8733
# Epoch 77/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3096 - accuracy: 0.8727
# Epoch 78/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3090 - accuracy: 0.8745
# Epoch 79/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3086 - accuracy: 0.8730
# Epoch 80/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3089 - accuracy: 0.8739
# Epoch 81/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3085 - accuracy: 0.8761
# Epoch 82/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3083 - accuracy: 0.8750
# Epoch 83/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3086 - accuracy: 0.8730
# Epoch 84/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3077 - accuracy: 0.8734
# Epoch 85/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3072 - accuracy: 0.8755
# Epoch 86/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3070 - accuracy: 0.8733
# Epoch 87/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3070 - accuracy: 0.8740
# Epoch 88/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3075 - accuracy: 0.8719
# Epoch 89/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3067 - accuracy: 0.8746
# Epoch 90/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3075 - accuracy: 0.8750
# Epoch 91/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3066 - accuracy: 0.8744
# Epoch 92/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3060 - accuracy: 0.8733
# Epoch 93/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3059 - accuracy: 0.8760
# Epoch 94/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3059 - accuracy: 0.8748
# Epoch 95/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3054 - accuracy: 0.8752
# Epoch 96/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3053 - accuracy: 0.8735
# Epoch 97/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3053 - accuracy: 0.8749
# Epoch 98/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3047 - accuracy: 0.8740
# Epoch 99/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3048 - accuracy: 0.8725
# Epoch 100/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3041 - accuracy: 0.8759

# %%
pred=model.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
score = model.evaluate(X_test,Y_test)
print("Loss: ",score[0])
print("Accuracy: ",score[1])
# Out:
# 63/63 [==============================] - 1s 2ms/step - loss: 0.3613 - accuracy: 0.8530
# Loss:  0.3612728416919708
# Accuracy:  0.8529999852180481
